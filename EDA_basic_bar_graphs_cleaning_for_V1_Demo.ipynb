# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# #### Unziping file

# %%
df = pd.read_csv('Data/Audience_LA.csv')
df
# Out:
#           Unnamed: 0    ZIP GENDER   AGE        DEMO_HH_INCOME ETHNICITY  \
# 0                  0  90290      F  35.0    $75,000 to $99,999     White
# 1                  1  90036      F  37.0  $100,000 to $149,999     White
# 2                  2  92376      M  51.0    $30,000 to $49,999     White
# 3                  3  91767      F  81.0     Less than $30,000     Asian
# 4                  4  92345      F  29.0    $30,000 to $49,999     White
# ...              ...    ...    ...   ...                   ...       ...
# 11945364    11945364  91354      F  53.0  $100,000 to $149,999  Hispanic
# 11945365    11945365  90262      M  45.0     Less than $30,000  Hispanic
# 11945366    11945366  91326      F  27.0    $30,000 to $49,999     Asian
# 11945367    11945367  92672      M  73.0  $100,000 to $149,999     White
# 11945368    11945368  92646      M  69.0  $150,000 to $199,999     White
#
#          HOMEOWNERSHIP_STATUS
# 0                   Homeowner
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0    ZIP GENDER   AGE        DEMO_HH_INCOME         ETHNICITY  \
# 0            0  90290      F  35.0    $75,000 to $99,999             White
# 1            1  90036      F  37.0  $100,000 to $149,999             White
# 2            2  92376      M  51.0    $30,000 to $49,999             White
# 3            3  91767      F  81.0     Less than $30,000             Asian
# 4            4  92345      F  29.0    $30,000 to $49,999             White
# 5            5  92225      M  63.0    $50,000 to $74,999          Hispanic
# 6            6  90032      F  69.0    $75,000 to $99,999          Hispanic
# 7            7  90301      M  69.0     Less than $30,000             White
# 8            8  90814      M  57.0    $50,000 to $74,999             White
# 9            9  90810      F  99.0    $30,000 to $49,999          Hispanic
# 10          10  92394      M  43.0     Less than $30,000             White
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# ZIP                          0
# GENDER                  120129
# AGE                         39
# DEMO_HH_INCOME               0
# ETHNICITY                    0
# HOMEOWNERSHIP_STATUS         0
# dtype: int64

# %% [markdown]
# # Dropping Null Values

# %%
df2= df.dropna()

# %%
df2.shape
# Out:
# (11825205, 7)

# %%
df.shape
# Out:
# (11945369, 7)

# %% [markdown]
# #### One Hot encoding
# ##### We started with Income

# %%
df2 = df2.rename(columns = {'ETHNICITY': 'RACE', 'Unnamed: 0':'ID'})

# %%
df2
# Out:
#                 ID    ZIP GENDER   AGE        DEMO_HH_INCOME      RACE  \
# 0                0  90290      F  35.0    $75,000 to $99,999     White
# 1                1  90036      F  37.0  $100,000 to $149,999     White
# 2                2  92376      M  51.0    $30,000 to $49,999     White
# 3                3  91767      F  81.0     Less than $30,000     Asian
# 4                4  92345      F  29.0    $30,000 to $49,999     White
# ...            ...    ...    ...   ...                   ...       ...
# 11945364  11945364  91354      F  53.0  $100,000 to $149,999  Hispanic
# 11945365  11945365  90262      M  45.0     Less than $30,000  Hispanic
# 11945366  11945366  91326      F  27.0    $30,000 to $49,999     Asian
# 11945367  11945367  92672      M  73.0  $100,000 to $149,999     White
# 11945368  11945368  92646      M  69.0  $150,000 to $199,999     White
#
#          HOMEOWNERSHIP_STATUS
# 0                   Homeowner
# 1                   Homeowner
# ...

# %%
dummies = pd.get_dummies(df2, columns=['DEMO_HH_INCOME'])

# %%
dummies.columns
# Out:
# Index(['ID', 'ZIP', 'GENDER', 'AGE', 'RACE', 'HOMEOWNERSHIP_STATUS',
#        'DEMO_HH_INCOME_$100,000 to $149,999',
#        'DEMO_HH_INCOME_$150,000 to $199,999',
#        'DEMO_HH_INCOME_$200,000 to $249,999', 'DEMO_HH_INCOME_$250,000 +',
#        'DEMO_HH_INCOME_$30,000 to $49,999',
#        'DEMO_HH_INCOME_$50,000 to $74,999',
#        'DEMO_HH_INCOME_$75,000 to $99,999',
#        'DEMO_HH_INCOME_Less than $30,000'],
#       dtype='object')

# %%
one_hot_income = dummies.rename(columns={"DEMO_HH_INCOME_$100,000 to $149,999": "100k - 149k", 
                                                  "DEMO_HH_INCOME_$150,000 to $199,999": "150k - 199k", 
                                                  "DEMO_HH_INCOME_$200,000 to $249,999": "200k - 249k", 
                                                  "DEMO_HH_INCOME_$250,000 +": "250k", 
                                                  "DEMO_HH_INCOME_$30,000 to $49,999": "30k - 49k", 
                                                  "DEMO_HH_INCOME_$50,000 to $74,999": "50k - 74k", 
                                                  "DEMO_HH_INCOME_$75,000 to $99,999": "75k - 99k", 
                                                  "DEMO_HH_INCOME_Less than $30,000": "0 - 30k"})

# %%
one_hot_income
# Out:
#                 ID    ZIP GENDER   AGE      RACE HOMEOWNERSHIP_STATUS  \
# 0                0  90290      F  35.0     White            Homeowner
# 1                1  90036      F  37.0     White            Homeowner
# 2                2  92376      M  51.0     White            Homeowner
# 3                3  91767      F  81.0     Asian            Homeowner
# 4                4  92345      F  29.0     White               Renter
# ...            ...    ...    ...   ...       ...                  ...
# 11945364  11945364  91354      F  53.0  Hispanic               Renter
# 11945365  11945365  90262      M  45.0  Hispanic            Homeowner
# 11945366  11945366  91326      F  27.0     Asian            Homeowner
# 11945367  11945367  92672      M  73.0     White            Homeowner
# 11945368  11945368  92646      M  69.0     White               Renter
#
#           100k - 149k  150k - 199k  200k - 249k  250k  30k - 49k  50k - 74k  \
# ...

# %% [markdown]
# ### Some basic exploratory analysis

# %%
one_hot_income.pivot_table(index='GENDER', columns='RACE', values="ID",aggfunc= 'count' )
# Out:
# RACE    African American   Asian  Hispanic    White
# GENDER
# F                 263592  662463   2241152  2927307
# M                 228621  672326   2013647  2816097

# %%
one_hot_income.pivot_table(index='HOMEOWNERSHIP_STATUS', columns='RACE', values="ID",aggfunc= 'count' )
# Out:
# RACE                  African American    Asian  Hispanic    White
# HOMEOWNERSHIP_STATUS
# Homeowner                       244909  1101331   3061644  4444847
# Renter                          247304   233458   1193155  1298557

# %%
one_hot_income['AGE'].hist()

# %%
np.unique(df2['DEMO_HH_INCOME'])
# Out:
# array(['$100,000 to $149,999', '$150,000 to $199,999',
#        '$200,000 to $249,999', '$250,000 +', '$30,000 to $49,999',
#        '$50,000 to $74,999', '$75,000 to $99,999', 'Less than $30,000'],
#       dtype=object)

# %%
#Shows counts of how many people are in each income bracket

fig_dims = (15, 4)
fig, ax = plt.pyplot.subplots(figsize=fig_dims)

sns.countplot(x="DEMO_HH_INCOME", order = ['Less than $30,000', '$30,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 to $149,999', '$150,000 to $199,999', '$200,000 to $249,999', '$250,000 +'], ax = ax, data=df2)

# %%
fig_dims = (15, 4)
fig, ax = plt.pyplot.subplots(figsize=fig_dims)
sns.countplot(x="DEMO_HH_INCOME", order = ['Less than $30,000', '$30,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 to $149,999', '$150,000 to $199,999', '$200,000 to $249,999', '$250,000 +'], hue = 'ETHNICITY', hue_order = ['White', 'Asian', 'Hispanic', 'African American'], ax = ax, data=df)

# %%
#Income by race - percentage. Shows the makeup of each individual income bracket
#Each income bracket adds to 100%

fig_dims = (15, 4)
fig, ax = plt.pyplot.subplots(figsize=fig_dims)

df_plot = df2

x,y = 'DEMO_HH_INCOME', 'RACE'

df_plot = df_plot.groupby(x)[y].value_counts(normalize=True).mul(100).rename('percent').reset_index()

sns.barplot(x=x,y='percent', order = ['Less than $30,000', '$30,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 to $149,999', '$150,000 to $199,999', '$200,000 to $249,999', '$250,000 +'], hue=y, hue_order = ['White', 'Asian', 'Hispanic', 'African American'], ax=ax, data = df_plot)

# %%
#race by income - shows the percentage of people of a certain race who are in a certain brackat. 
#all the bars for one race add to 100%

fig_dims = (15, 4)
fig, ax = plt.pyplot.subplots(figsize=fig_dims)

df_plot = df

x,y = 'DEMO_HH_INCOME', 'ETHNICITY'

x,y = 'ETHNICITY', 'DEMO_HH_INCOME'


df_plot = df_plot.groupby(x)[y].value_counts(normalize=True).mul(100).rename('percent').reset_index()

sns.barplot(x=y, y='percent', hue=x, order = ['Less than $30,000', '$30,000 to $49,999', '$50,000 to $74,999', '$75,000 to $99,999', '$100,000 to $149,999', '$150,000 to $199,999', '$200,000 to $249,999', '$250,000 +'], hue_order = ['White', 'Asian', 'Hispanic', 'African American'], ax=ax, data = df_plot)
